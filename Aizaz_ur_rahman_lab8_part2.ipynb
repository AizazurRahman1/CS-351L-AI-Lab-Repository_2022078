# %% [markdown]
# <a href="https://colab.research.google.com/github/AizazurRahman1/CS-351L-AI-Lab-Repository_2022078/blob/main/Aizaz_ur_rahman_lab8_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer, StandardScaler
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

np.random.seed(42)
tf.random.set_seed(42)

# Load the Iris dataset
from sklearn.datasets import load_iris
iris = load_iris()
X_iris = iris.data
y_iris = iris.target
iris_target_names = iris.target_names

iris_encoder = LabelBinarizer()
y_iris_encoded = iris_encoder.fit_transform(y_iris)

iris_scaler = StandardScaler()
X_iris_scaled = iris_scaler.fit_transform(X_iris)

X_iris_train, X_iris_test, y_iris_train, y_iris_test = train_test_split(X_iris_scaled, y_iris_encoded, test_size=0.3, random_state=42)

# Iris Model
iris_model = Sequential([
    Dense(8, activation='relu', input_shape=(X_iris_train.shape[1],), name="Hidden_Layer_1"),
    Dense(16, activation='relu', name="Hidden_Layer_2"),
    Dense(y_iris_train.shape[1], activation='softmax', name="Output_Layer")
])

iris_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

iris_history = iris_model.fit(X_iris_train, y_iris_train, epochs=50, validation_split=0.2, batch_size=8, verbose=1)

iris_test_loss, iris_test_accuracy = iris_model.evaluate(X_iris_test, y_iris_test, verbose=0)

# Load the Wine dataset
from sklearn.datasets import load_wine
wine = load_wine()
X_wine = wine.data
y_wine = wine.target
wine_target_names = wine.target_names

wine_encoder = LabelBinarizer()
y_wine_encoded = wine_encoder.fit_transform(y_wine)

wine_scaler = StandardScaler()
X_wine_scaled = wine_scaler.fit_transform(X_wine)

X_wine_train, X_wine_test, y_wine_train, y_wine_test = train_test_split(X_wine_scaled, y_wine_encoded, test_size=0.3, random_state=42)

# Wine Model
wine_model = Sequential([
    Dense(8, activation='relu', input_shape=(X_wine_train.shape[1],), name="Hidden_Layer_1"),
    Dense(16, activation='relu', name="Hidden_Layer_2"),
    Dense(y_wine_train.shape[1], activation='softmax', name="Output_Layer")
])

wine_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

wine_history = wine_model.fit(X_wine_train, y_wine_train, epochs=50, validation_split=0.2, batch_size=8, verbose=1)

wine_test_loss, wine_test_accuracy = wine_model.evaluate(X_wine_test, y_wine_test, verbose=0)

# Visualization: Iris
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(iris_history.history['loss'], label='Iris Training Loss')
plt.plot(iris_history.history['val_loss'], label='Iris Validation Loss')
plt.title('Iris Model: Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(iris_history.history['accuracy'], label='Iris Training Accuracy')
plt.plot(iris_history.history['val_accuracy'], label='Iris Validation Accuracy')
plt.title('Iris Model: Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# Visualization: Wine
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(wine_history.history['loss'], label='Wine Training Loss')
plt.plot(wine_history.history['val_loss'], label='Wine Validation Loss')
plt.title('Wine Model: Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(wine_history.history['accuracy'], label='Wine Training Accuracy')
plt.plot(wine_history.history['val_accuracy'], label='Wine Validation Accuracy')
plt.title('Wine Model: Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# Compare Metrics
print(f"Iris Model - Test Loss: {iris_test_loss:.4f}, Test Accuracy: {iris_test_accuracy:.4f}")
print(f"Wine Model - Test Loss: {wine_test_loss:.4f}, Test Accuracy: {wine_test_accuracy:.4f}")

# Confusion Matrices
iris_y_pred = iris_model.predict(X_iris_test)
iris_y_pred_classes = np.argmax(iris_y_pred, axis=1)
iris_y_true_classes = np.argmax(y_iris_test, axis=1)
ConfusionMatrixDisplay.from_predictions(iris_y_true_classes, iris_y_pred_classes, display_labels=iris_target_names, cmap="Blues")
plt.title("Iris Model - Confusion Matrix")
plt.show()

wine_y_pred = wine_model.predict(X_wine_test)
wine_y_pred_classes = np.argmax(wine_y_pred, axis=1)
wine_y_true_classes = np.argmax(y_wine_test, axis=1)
ConfusionMatrixDisplay.from_predictions(wine_y_true_classes, wine_y_pred_classes, display_labels=wine_target_names, cmap="Blues")
plt.title("Wine Model - Confusion Matrix")
plt.show()

# Discussion and Analysis
print("Discussion and Analysis:")
print("1. The effect of adding additional layers:")
print("   Adding more layers with increased neurons generally improved the capacity of the model to learn more complex patterns. This is evident in both datasets with better accuracy.")
print("2. Performance difference between Iris and Wine datasets:")
print("   The Wine dataset, having more features, benefits more from the additional complexity of the model. The Iris dataset, being simpler, shows comparable performance.")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 0.2297 - loss: 1.0983 - val_accuracy: 0.1905 - val_loss: 1.1032
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2297 - loss: 1.0517 - val_accuracy: 0.3333 - val_loss: 1.0645
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.2753 - loss: 1.0103 - val_accuracy: 0.3333 - val_loss: 1.0277
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3426 - loss: 0.9700 - val_accuracy: 0.5714 - val_loss: 0.9918
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6104 - loss: 0.9304 - val_accuracy: 0.7143 - val_loss: 0.9564
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7714 - loss: 0.8915 - val_accuracy: 0.7143 - val_loss: 0.9214
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7714 - loss: 0.8531 - val_accuracy: 0.7143 - val_loss: 0.8868
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7714 - loss: 0.8153 - val_accuracy: 0.7619 - val_loss: 0.8523
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7745 - loss: 0.7782 - val_accuracy: 0.7619 - val_loss: 0.8185
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7745 - loss: 0.7424 - val_accuracy: 0.7619 - val_loss: 0.7857
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7775 - loss: 0.7077 - val_accuracy: 0.8095 - val_loss: 0.7527
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7944 - loss: 0.6742 - val_accuracy: 0.8095 - val_loss: 0.7214
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7944 - loss: 0.6426 - val_accuracy: 0.8095 - val_loss: 0.6920
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7944 - loss: 0.6121 - val_accuracy: 0.8095 - val_loss: 0.6650
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8356 - loss: 0.5819 - val_accuracy: 0.8095 - val_loss: 0.6403
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8298 - loss: 0.5534 - val_accuracy: 0.8571 - val_loss: 0.6176
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8298 - loss: 0.5267 - val_accuracy: 0.8571 - val_loss: 0.5961
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8623 - loss: 0.5015 - val_accuracy: 0.8571 - val_loss: 0.5748
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8711 - loss: 0.4775 - val_accuracy: 0.9048 - val_loss: 0.5552
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9121 - loss: 0.4547 - val_accuracy: 0.9048 - val_loss: 0.5371
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9121 - loss: 0.4329 - val_accuracy: 0.9048 - val_loss: 0.5202
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9175 - loss: 0.4119 - val_accuracy: 0.9048 - val_loss: 0.5042
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9175 - loss: 0.3915 - val_accuracy: 0.9048 - val_loss: 0.4896
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9175 - loss: 0.3720 - val_accuracy: 0.9048 - val_loss: 0.4770
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7965 - loss: 0.6178 - val_accuracy: 0.9200 - val_loss: 0.5938
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8384 - loss: 0.5822 - val_accuracy: 0.9200 - val_loss: 0.5539
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8343 - loss: 0.5486 - val_accuracy: 0.9200 - val_loss: 0.5154
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8501 - loss: 0.5152 - val_accuracy: 0.9200 - val_loss: 0.4777
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8501 - loss: 0.4822 - val_accuracy: 0.9200 - val_loss: 0.4407
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8501 - loss: 0.4498 - val_accuracy: 0.9200 - val_loss: 0.4061
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8660 - loss: 0.4188 - val_accuracy: 0.9200 - val_loss: 0.3738
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8709 - loss: 0.3890 - val_accuracy: 0.9200 - val_loss: 0.3425
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8837 - loss: 0.3603 - val_accuracy: 0.9200 - val_loss: 0.3113
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9136 - loss: 0.3335 - val_accuracy: 0.9200 - val_loss: 0.2826
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9136 - loss: 0.3085 - val_accuracy: 0.9200 - val_loss: 0.2565
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9136 - loss: 0.2849 - val_accuracy: 0.9600 - val_loss: 0.2330
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9136 - loss: 0.2635 - val_accuracy: 0.9600 - val_loss: 0.2122
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9136 - loss: 0.2442 - val_accuracy: 0.9600 - val_loss: 0.1942
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9224 - loss: 0.2271 - val_accuracy: 0.9600 - val_loss: 0.1782
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9330 - loss: 0.2120 - val_accuracy: 0.9600 - val_loss: 0.1638
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9330 - loss: 0.1988 - val_accuracy: 0.9600 - val_loss: 0.1508
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9330 - loss: 0.1873 - val_accuracy: 1.0000 - val_loss: 0.1392
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9330 - loss: 0.1771 - val_accuracy: 1.0000 - val_loss: 0.1289
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9330 - loss: 0.1681 - val_accuracy: 1.0000 - val_loss: 0.1199
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9330 - loss: 0.1601 - val_accuracy: 1.0000 - val_loss: 0.1123
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9621 - loss: 0.1531 - val_accuracy: 1.0000 - val_loss: 0.1056
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9643 - loss: 0.1466 - val_accuracy: 1.0000 - val_loss: 0.0996
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9643 - loss: 0.1407 - val_accuracy: 1.0000 - val_loss: 0.0941
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9643 - loss: 0.1351 - val_accuracy: 1.0000 - val_loss: 0.0894
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9716 - loss: 0.1297 - val_accuracy: 1.0000 - val_loss: 0.0852
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9716 - loss: 0.1246 - val_accuracy: 1.0000 - val_loss: 0.0816
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9716 - loss: 0.1199 - val_accuracy: 1.0000 - val_loss: 0.0778
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9716 - loss: 0.1153 - val_accuracy: 1.0000 - val_loss: 0.0741
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9716 - loss: 0.1111 - val_accuracy: 1.0000 - val_loss: 0.0709
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9716 - loss: 0.1074 - val_accuracy: 1.0000 - val_loss: 0.0677
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9716 - loss: 0.1038 - val_accuracy: 1.0000 - val_loss: 0.0647
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9716 - loss: 0.1004 - val_accuracy: 1.0000 - val_loss: 0.0621
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9716 - loss: 0.0974 - val_accuracy: 1.0000 - val_loss: 0.0596
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9716 - loss: 0.0947 - val_accuracy: 1.0000 - val_loss: 0.0573
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9716 - loss: 0.0923 - val_accuracy: 1.0000 - val_loss: 0.0551
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9716 - loss: 0.0900 - val_accuracy: 1.0000 - val_loss: 0.0532
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9716 - loss: 0.0877 - val_accuracy: 1.0000 - val_loss: 0.0514
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9716 - loss: 0.0853 - val_accuracy: 1.0000 - val_loss: 0.0493
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d2b5f30b490> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iris Model - Test Loss: 0.1429, Test Accuracy: 0.9778
# Wine Model - Test Loss: 0.0326, Test Accuracy: 1.0000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d2b5f30b490> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Discussion and Analysis:
# 1. The effect of adding additional layers:
#    Adding more layers with increased neurons generally improved the capacity of the model to learn more complex patterns. This is evident in both datasets with better accuracy.
# 2. Performance difference between Iris and Wine datasets:
#    The Wine dataset, having more features, benefits more from the additional complexity of the model. The Iris dataset, being simpler, shows comparable performance.
